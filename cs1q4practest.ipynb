# %% [markdown]
# <a href="https://colab.research.google.com/github/dalandanshek/cs1q4practest/blob/main/cs1q4practest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def CALCULATE():
  return (score1 + score2 + score3) / 3

print("Welcome to the Student Score Analyzer!")
name = input("Please enter your name: ")
score1 = int(input("Enter quiz 1 score: "))
score2 = int(input("Enter quiz 2 score: "))
score3 = int(input("Enter quiz 3 score: "))

print("Calculating results..")

print("Hello,",name,"!")

print("Your average quiz score is:",CALCULATE())
if (CALCULATE()) >= 75:
  print("Status: PASSED")
else:
  print("Status: FAILED")

print("Thank you for using the Student Score Analyzer!")
